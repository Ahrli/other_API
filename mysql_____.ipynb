# %%
import pandas
from futuquant import *
from pypinyin import *

pysqldf = lambda q: sqldf(q, globals())
from redis import StrictRedis
from sshtunnel import SSHTunnelForwarder
from pandasql import sqldf
from sqlalchemy import create_engine
import pymysql
import requests
import json
import pandas as pd
import arrow

server = SSHTunnelForwarder(
        ("47.100.229.250", 22),
        ssh_username="root",
        ssh_password="LOOP2themoon",
        remote_bind_address=("192.168.82.172", 3306))
server.start()
engine = create_engine(f'mysql+pymysql://root:LOOP2themoon@127.0.0.1:{server.local_bind_port}/iquant_stock?charset=utf8')

sql = f"select * from t_stock "
df = pd.read_sql(sql, engine)

# %%
print(df)
# Out:
#           id       code                                               name  \
# 0          1   HK.00001                                                 长和
# 1          2   HK.00002                                               中电控股
# 2          3   HK.00003                                             香港中华煤气
# 3          4   HK.00004                                              九龙仓集团
# 4          5   HK.00005                                               汇丰控股
# 5          6   HK.00006                                               电能实业
# 6          7   HK.00007                                             香港金融集团
# 7          8   HK.00008                                               电讯盈科
# 8          9   HK.00009                                               九号运通
# 9         10   HK.00010                                               恒隆集团
# 10        11   HK.00011                                               恒生银行
# ...

# %%
df['full_spell'] = df['full_spell'].apply(lambda full_spell : full_spell.replace(" ",""))

# %%
print(df)
# Out:
#           id       code                                               name  \
# 0          1   HK.00001                                                 长和
# 1          2   HK.00002                                               中电控股
# 2          3   HK.00003                                             香港中华煤气
# 3          4   HK.00004                                              九龙仓集团
# 4          5   HK.00005                                               汇丰控股
# 5          6   HK.00006                                               电能实业
# 6          7   HK.00007                                             香港金融集团
# 7          8   HK.00008                                               电讯盈科
# 8          9   HK.00009                                               九号运通
# 9         10   HK.00010                                               恒隆集团
# 10        11   HK.00011                                               恒生银行
# ...
