# %% [markdown]
# # intrinio

# %% [markdown]
# https://github.com/intrinio/python-sdk

# %% [markdown]
# https://intrinio.com/account/access_keys
#
# - yiqidangqian@foxmail.com
# - LOOP2themoon

# %% [markdown]
# OjY5ZjAxZTM1M2RjZDQyMmQwYWUxOTcxZmRjYWFkNjdm
#
# 2aa377ed0fe0fbdf9c96263c941494d3
#
# 5d7a67608228b665ca77e52094eb707b

# %% [markdown]
# OmIwNDIzMDk2YjRkYTNhZmRmZGM2ODc1YzZiZjJhMzJm
#
# 2aa377ed0fe0fbdf9c96263c941494d3
#
# b844f511a50849733eeda2899f042f9e

# %% [markdown]
# OjkzYmNhYWRiYTAzMTM4YzhmYjliODY1MTM3ZDQ1Y2Fj

# %%
from __future__ import print_function
import time
import intrinio_sdk
from intrinio_sdk.rest import ApiException
from pprint import pprint

intrinio_sdk.ApiClient().configuration.api_key['api_key'] = 'OjkzYmNhYWRiYTAzMTM4YzhmYjliODY1MTM3ZDQ1Y2Fj' 

company_api = intrinio_sdk.CompanyApi()

try:
    api_response = company_api.filter_companies()
    pprint(api_response)
except ApiException as e:
    print(f"Exception when calling CompanyApi->filter_companies: {e}\n")
# Out:
# {'companies': [{'cik': '0000320193',
#                 'id': 'com_NX6GzO',
#                 'lei': 'HWUPKR0MPOU8FGXBT394',
#                 'name': 'Apple Inc',
#                 'ticker': 'AAPL'},
#                {'cik': '0000034088',
#                 'id': 'com_2zvNzA',
#                 'lei': 'J3WHBG0MTS7O8ZVMDC91',
#                 'name': 'Exxon Mobil Corp',
#                 'ticker': 'XOM'},
#                {'cik': '0001341439',
#                 'id': 'com_0XLDXx',
#                 'lei': '1Z4GXXU7ZHVWFCD8TV52',
#                 'name': 'Oracle Corp',
#                 'ticker': 'ORCL'},
#                {'cik': '0000021344',
#                 'id': 'com_VXWJgv',
#                 'lei': 'UWJKFUJFZ02DKWI3RY53',
#                 'name': 'Coca-Cola Co',
#                 'ticker': 'KO'},
#                {'cik': '0000050863',
#                 'id': 'com_NgYGzd',
#                 'lei': 'KNX4USFCNGPY45LOCE31',
#                 'name': 'Intel Corp',
# ...

# %% [markdown]
# ## 交易所

# %%
stock_exchanges_api = intrinio_sdk.StockExchangeApi()

# %%
try:
    api_response = stock_exchanges_api.get_all_stock_exchanges()
    pprint(api_response)
except ApiException as e:stock_exchanges_api.get_all_stock_exchanges()
    print(f"Exception when calling CompanyApi->filter_companies: {e}\n")
# Out:
# {'next_page': None,
#  'stock_exchanges': [{'acronym': 'LIT',
#                       'city': 'VILNIUS',
#                       'country': 'LITHUANIA',
#                       'country_code': 'LT',
#                       'first_stock_price_date': datetime.date(2004, 5, 14),
#                       'id': 'sxg_xgxM8X',
#                       'last_stock_price_date': datetime.date(2018, 12, 21),
#                       'mic': 'XLIT',
#                       'name': 'AB NASDAQ VILNIUS',
#                       'website': 'WWW.NASDAQBALTIC.COM'},
#                      {'acronym': 'ADSM',
#                       'city': 'ABU DHABI',
#                       'country': 'UNITED ARAB EMIRATES',
#                       'country_code': 'AE',
#                       'first_stock_price_date': datetime.date(2002, 1, 2),
#                       'id': 'sxg_2z9OBg',
#                       'last_stock_price_date': datetime.date(2018, 12, 26),
#                       'mic': 'XADS',
# ...

# %% [markdown]
# ## 股票

# %%
stock_exchange_api = intrinio_sdk.StockExchangeApi()

identifier = 'XSHG' # str | A Stock Exchange identifier (MIC or Intrinio ID) 证券交易所标识符
date = '2018-08-14' # date | The date for which to return prices (optional)
next_page = '' # str | Gets the next page of data from a previous API call (optional)

try:
    api_response = stock_exchange_api.get_stock_exchange_prices(identifier, date=date, next_page=next_page)
    pprint(api_response)
except ApiException as e:
    print(f"Exception when calling StockExchangeApi->get_stock_exchange_prices: {e}\n")
# Out:
# {'next_page': 'MTgwMjc=',
#  'stock_exchange': {'acronym': 'SSE',
#                     'city': 'SHANGHAI',
#                     'country': 'CHINA',
#                     'country_code': 'CN',
#                     'first_stock_price_date': datetime.date(2006, 4, 28),
#                     'id': 'sxg_0XLDXx',
#                     'last_stock_price_date': datetime.date(2018, 12, 26),
#                     'mic': 'XSHG',
#                     'name': 'SHANGHAI STOCK EXCHANGE',
#                     'website': 'HTTP://WWW.SSE.COM.CN'},
#  'stock_prices': [{'adj_close': 7.89,
#                    'adj_high': 7.94,
#                    'adj_low': 7.82,
#                    'adj_open': 7.83,
#                    'adj_volume': 905770.0,
#                    'close': 7.89,
#                    'date': datetime.date(2018, 8, 14),
#                    'frequency': 'daily',
#                    'high': 7.94,
#                    'intraperiod': False,
#                    'low': 7.82,
# ...

# %% [markdown]
# ```zsh
# 东京 Tokyo
# 法拉克福 Frankfurt
# 伦敦 London
# 巴黎 Paris
# 多伦多 Toronto
# ```

# %% [markdown]
# -----------

# %% [markdown]
# https://www.alphavantage.co/

# %% [markdown]
# 美 /'væntɪdʒ/

# %% [markdown]
# # vantage

# %%
vantageKey = 'ENT3FCK1B4AG0ZBW'

# %%
vantageKey = '7M4BHLI9XYCDKXSO'

# %% [markdown]
# ### 安装module

# %%
# !pip install alpha_vantage
# Out:
# Looking in indexes: https://pypi.doubanio.com/simple/
# ...

# %%
# !pip show alpha_vantage
# Out:
# Name: alpha-vantage
# Version: 2.1.0
# Summary: Python module to get stock data from the Alpha Vantage Api
# Home-page: https://github.com/RomelTorres/alpha_vantage
# Author: Romel J. Torres
# Author-email: romel.torres@gmail.com
# License: MIT
# Location: f:\anaconda3\lib\site-packages
# Requires: requests
# Required-by:

# %% [markdown]
# ### 安装download module

# %%
# !pip install alpha-vantage-downloader
# Out:
# Looking in indexes: https://pypi.doubanio.com/simple/
# ...

# %%
# !pip show alpha-vantage-downloader
# Out:
# Name: alpha-vantage-downloader
# Version: 0.0.5
# Summary: A simple wrapper around alpha vantage api
# Home-page: https://github.com/fricative/alpha_vantage_downloader
# Author: fricative
# Author-email: keye906@yahoo.com
# License: UNKNOWN
# Location: f:\anaconda3\lib\site-packages
# Requires: pandas
# Required-by:

# %% [markdown]
# ------

# %% [markdown]
# 文档 https://github.com/RomelTorres/alpha_vantage

# %% [markdown]
# 实时接口是分钟级别

# %%
import alpha_vantage

# %%
from alpha_vantage.timeseries import TimeSeries
ts = TimeSeries(key=vantageKey,output_format='pandas')
# Get json object with the intraday data and another with  the call's metadata

# %%
ts.

# %% [markdown]
# 实时接口

# %%
data, meta_data = ts.get_intraday(symbol='GOOGL',
                                  #'hk00700',
                                  interval='1min', # 1min，5min，15min，30min，60min
                                  outputsize='full')

# %%
meta_data
# Out:
# {'1. Information': 'Intraday (1min) open, high, low, close prices and volume',
#  '2. Symbol': 'GOOGL',
#  '3. Last Refreshed': '2018-10-09 15:59:00',
#  '4. Interval': '1min',
#  '5. Output Size': 'Full size',
#  '6. Time Zone': 'US/Eastern'}

# %%
data.tail()
# Out:
#                       1. open   2. high     3. low   4. close  5. volume
# date
# 2018-10-10 15:56:00  1098.895  1099.630  1093.4700  1094.0300    39363.0
# 2018-10-10 15:57:00  1094.010  1094.925  1092.3900  1094.3750    39581.0
# 2018-10-10 15:58:00  1094.770  1095.800  1093.3400  1095.0350    30238.0
# 2018-10-10 15:59:00  1095.465  1096.530  1094.3400  1094.8650    56188.0
# 2018-10-10 16:00:00  1094.400  1096.465  1091.5699  1091.5699   125474.0

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies
import matplotlib.pyplot as plt

cc = CryptoCurrencies(key=vantageKey, output_format='pandas')
data, meta_data = cc.get_digital_currency_intraday(symbol='BTC', market='CNY')
data['1b. price (USD)'].plot()
plt.tight_layout()
plt.title('Intraday value for bitcoin (BTC)')
plt.grid()
plt.show()

# %%
len(data)
# Out:
# 1874

# %%
data.tail(3)
# Out:
#                      1. open    2. high     3. low   4. close  5. volume
# date
# 2018-10-09 15:57:00  1144.95  1145.0601  1144.8000  1144.9000    17815.0
# 2018-10-09 15:58:00  1145.09  1145.4600  1144.5699  1144.5699    19002.0
# 2018-10-09 15:59:00  1144.62  1145.5699  1144.5699  1145.3300    44970.0

# %%
data, meta_data = ts.get_daily(symbol='GOOGL',
                               outputsize='full')

# %%
data.head()
# Out:
#             1. open  2. high  3. low  4. close   5. volume
# date
# 2004-08-19   100.01   104.06   95.96   100.335  44659000.0
# 2004-08-20   101.01   109.08  100.50   108.310  22834300.0
# 2004-08-23   110.76   113.48  109.05   109.400  18256100.0
# 2004-08-24   111.24   111.60  103.57   104.870  15247300.0
# 2004-08-25   104.76   108.00  103.88   106.000   9188600.0

# %% [markdown]
# 历史数据，日级别

# %% [markdown]
# -------------

# %%
data, meta_data = ts.get_daily(symbol='600519',
                               outputsize='full')

# %%
data.head()
# Out:
#             1. open  2. high  3. low  4. close  5. volume
# date
# 2018-01-02   700.00   710.16  689.89    703.85  4961250.0
# 2018-01-03   701.50   721.40  699.74    715.86  5201940.0
# 2018-01-04   721.40   743.50  719.33    737.07  7220510.0
# 2018-01-05   741.00   746.03  728.22    738.36  3998910.0
# 2018-01-08   735.02   756.50  735.02    752.13  5220460.0

# %% [markdown]
# ----------------

# %% [markdown]
# Auth Token: `5ad45e5247e9f3ddc3a85005ea92c69d1bc4a552`

# %% [markdown]
# # tiingo

# %%
import tiingo

# %%
# !pip show tiingo
# Out:
# Name: tiingo
# Version: 0.8.0
# Summary: REST Client for Tiingo Data Platform API
# Home-page: https://github.com/hydrosquall/tiingo-python
# Author: Cameron Yick
# Author-email: cameron.yick@enigma.com
# License: MIT license
# Location: f:\anaconda3\lib\site-packages
# Requires: requests
# Required-by:

# %%
from tiingo import TiingoClient
config = {}

# To reuse the same HTTP Session across API calls (and have better performance), include a session key.
config['session'] = True

# If you don't have your API key as an environment variable,
# pass it in via a configuration dictionary.
config['api_key'] = "5ad45e5247e9f3ddc3a85005ea92c69d1bc4a552"

# Initialize
client = TiingoClient(config)

# %%
# Get Ticker
ticker_metadata = client.get_ticker_metadata("GOOGL")

# %%
ticker_metadata
# Out:
# {'ticker': 'GOOGL',
#  'name': 'Alphabet Inc.("Google") - Class A',
#  'exchangeCode': 'NASDAQ',
#  'startDate': '2004-08-19',
#  'endDate': '2018-09-27',
# ...

# %%
ticker_history = client.get_dataframe("GOOGL")

# %%
client.get_dataframe?

# %%
ticker_history
# Out:
#             adjClose  adjHigh   adjLow  adjOpen  adjVolume    close  divCash  \
# date
# 2018-09-27   1207.36  1216.86  1198.05   1200.0    1812802  1207.36      0.0
#
#                high      low    open  splitFactor   volume
# date
# 2018-09-27  1216.86  1198.05  1200.0          1.0  1812802

# %%
client.

# %%
# Get latest prices, based on 3+ sources as JSON, sampled weekly
client.get_dataframe("GOOGL", frequency="weekly")
# Out:
#             adjClose  adjHigh   adjLow  adjOpen  adjVolume    close  divCash  \
# date
# 2018-09-27   1207.36  1216.86  1198.05   1200.0    1812802  1207.36      0.0
#
#                high      low    open  splitFactor   volume
# date
# 2018-09-27  1216.86  1198.05  1200.0          1.0  1812802

# %%
client.get_dataframe(#['GOOGL', 'AAPL'],
                     tickers='000001',
                                      frequency='weekly',
                                      #metric_name='volume',
                                      startDate='2017-05-15',
                                      endDate='2017-05-31').head()
# Out:
#             adjClose   adjHigh    adjLow   adjOpen  adjVolume  close  divCash  \
# date
# 2017-05-19  8.432773  8.588037  8.423069  8.578333  146388231   8.69      0.0
# 2017-05-26  8.830637  8.869453  8.384253  8.413365  384932638   9.10      0.0
# 2017-06-02  8.898565  9.015013  8.791821  8.830637  237015077   9.17      0.0
#
#             high   low  open  splitFactor     volume
# date
# 2017-05-19  8.85  8.68  8.84          1.0  146388231
# 2017-05-26  9.14  8.64  8.67          1.0  384932638
# 2017-06-02  9.29  9.06  9.10          1.0  237015077

# %%
client.get_dataframe?

# %%
client.get_dataframe?

# %%
len(client.list_fund_tickers()) # 基金
# Out:
# 34630

# %%
len(client.list_stock_tickers()) # 股票
# Out:
# 31644

# %%
data = client.list_stock_tickers()

# %%
listData = [{"tocker":i['ticker'],
  "exchange":i['exchange'],
  "assetType":i['assetType'],
  "priceCurrency":i['priceCurrency'],
  "startDate":i['startDate'],
  "endDate":i['endDate'],} for i in data]

# %%
dfq = pd.DataFrame(listData)

# %%
set(list(dfq['exchange']))
# Out:
# {'',
#  'AMEX',
#  'BATS',
#  'NASDAQ',
#  'NMFQS',
#  'NYSE',
#  'NYSE ARCA',
#  'NYSE MKT',
#  'OTCBB',
#  'OTCMKTS',
#  'PINK',
#  'SHE',
#  'SHG'}

# %%
data[:10]
# Out:
# [OrderedDict([('ticker', '000001'),
#               ('exchange', 'SHE'),
#               ('assetType', 'Stock'),
#               ('priceCurrency', 'CNY'),
#               ('startDate', '2007-08-30'),
#               ('endDate', '2018-10-09')]),
#  OrderedDict([('ticker', '000002'),
#               ('exchange', 'SHE'),
#               ('assetType', 'Stock'),
#               ('priceCurrency', 'CNY'),
#               ('startDate', '2000-01-04'),
#               ('endDate', '2018-10-09')]),
#  OrderedDict([('ticker', '000004'),
#               ('exchange', 'SHE'),
#               ('assetType', 'Stock'),
#               ('priceCurrency', 'CNY'),
#               ('startDate', '2007-08-31'),
#               ('endDate', '2018-09-28')]),
#  OrderedDict([('ticker', '000005'),
#               ('exchange', 'SHE'),
#               ('assetType', 'Stock'),
#               ('priceCurrency', 'CNY'),
#               ('startDate', '2001-01-02'),
#               ('endDate', '2018-10-09')]),
# ...

# %%
data[4567:4789]
# Out:
# [OrderedDict([('ticker', 'AIVTF'),
#               ('exchange', 'OTCMKTS'),
#               ('assetType', 'Stock'),
#               ('priceCurrency', 'USD'),
#               ('startDate', '2016-12-28'),
#               ('endDate', '2018-09-24')]),
#  OrderedDict([('ticker', 'AIW'),
#               ('exchange', 'NYSE'),
#               ('assetType', 'Stock'),
#               ('priceCurrency', 'USD'),
#               ('startDate', '2013-05-06'),
#               ('endDate', '2018-10-05')]),
#  OrderedDict([('ticker', 'AIXG'),
#               ('exchange', 'NASDAQ'),
#               ('assetType', 'Stock'),
#               ('priceCurrency', 'USD'),
#               ('startDate', '2005-03-11'),
#               ('endDate', '2017-07-18')]),
#  OrderedDict([('ticker', 'AIXN'),
#               ('exchange', 'PINK'),
#               ('assetType', 'Stock'),
#               ('priceCurrency', 'USD'),
#               ('startDate', '2018-02-05'),
#               ('endDate', '2018-10-02')]),
# ...

# %%
import pandas as pd

# %%
pd.read_json(client.list_stock_tickers())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-06b7f90cf4c7> in <module>()
# ----> 1 pd.read_json(client.list_stock_tickers())
#
# F:\Anaconda3\lib\site-packages\pandas\io\json\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     406     compression = _infer_compression(path_or_buf, compression)
#     407     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 408         path_or_buf, encoding=encoding, compression=compression,
#     409     )
#     410
#
# F:\Anaconda3\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode)
#     216     if not is_file_like(filepath_or_buffer):
# ...

# %%
client.get_dataframe('GOOGL',
                    #"000001.sh",
                    # tickers='000001',
                     frequency='1Min',
                     startDate='2017-05-15',
                     endDate='2018-05-31')
# Out:
#                        close      high       low      open
# date
# 2018-05-30 10:40:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:41:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:42:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:43:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:44:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:45:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:46:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:47:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:48:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:49:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:50:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:51:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:52:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:53:00  1067.95  1067.950  1067.950  1067.950
# 2018-05-30 10:54:00  1067.95  1067.950  1067.950  1067.950
# ...

# %%
# Out:
# ERROR:root:b'{"detail":"You do not have permission to access the News API"}'
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# F:\Anaconda3\lib\site-packages\tiingo\restclient.py in _request(self, method, url, **kwargs)
#      52         try:
# ---> 53             resp.raise_for_status()
#      54         except HTTPError as e:
#
# F:\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     934         if http_error_msg:
# --> 935             raise HTTPError(http_error_msg, response=self)
#     936
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.tiingo.com/tiingo/news?limit=100&offset=0&sortBy=publishedDate&tickers=000001
#
# During handling of the above exception, another exception occurred:
#
# RestClientError                           Traceback (most recent call last)
# <ipython-input-144-6947e2ae560c> in <module>()
# ...

# %%
ticker_price
# Out:
# [{'adjClose': 1207.36,
#   'adjHigh': 1216.86,
#   'adjLow': 1198.05,
#   'adjOpen': 1200.0,
#   'adjVolume': 1812802,
#   'close': 1207.36,
#   'date': '2018-09-27T00:00:00+00:00',
#   'divCash': 0.0,
#   'high': 1216.86,
#   'low': 1198.05,
#   'open': 1200.0,
#   'splitFactor': 1.0,
#   'volume': 1812802}]

# %%
# Get historical GOOGL prices from August 2017 as JSON, sampled daily
historical_prices = client.get_ticker_price("GOOGL",
                                            fmt='json',
                                            startDate='2017-08-01',
                                            endDate='2017-08-31',
                                            frequency='daily')

# %%
historical_prices
# Out:
# [{'date': '2017-08-01T00:00:00.000Z',
#   'close': 946.56,
#   'high': 954.49,
#   'low': 944.96,
#   'open': 947.81,
#   'volume': 1205799,
#   'adjClose': 946.56,
#   'adjHigh': 954.49,
#   'adjLow': 944.96,
#   'adjOpen': 947.81,
#   'adjVolume': 1205799,
#   'divCash': 0.0,
#   'splitFactor': 1.0},
#  {'date': '2017-08-02T00:00:00.000Z',
#   'close': 947.64,
#   'high': 949.1,
#   'low': 932.52,
#   'open': 948.37,
#   'volume': 2019979,
#   'adjClose': 947.64,
#   'adjHigh': 949.1,
#   'adjLow': 932.52,
#   'adjOpen': 948.37,
#   'adjVolume': 2019979,
#   'divCash': 0.0,
#   'splitFactor': 1.0},
#  {'date': '2017-08-03T00:00:00.000Z',
#   'close': 940.3,
#   'high': 950.0,
#   'low': 939.44,
#   'open': 949.1,
#   'volume': 1028591,
#   'adjClose': 940.3,
#   'adjHigh': 950.0,
#   'adjLow': 939.44,
#   'adjOpen': 949.1,
#   'adjVolume': 1028591,
#   'divCash': 0.0,
#   'splitFactor': 1.0},
#  {'date': '2017-08-04T00:00:00.000Z',
#   'close': 945.79,
#   'high': 947.54,
# ...

# %%
import requests

headers = {
       'Content-Type': 'application/json',
       'Authorization' : 'Token 5ad45e5247e9f3ddc3a85005ea92c69d1bc4a552'
       }
requestResponse = requests.get("https://api.tiingo.com/api/test/",
                                  headers=headers)
print (requestResponse.json())

#OR we can use the token directly in the url
import requests

headers = {
       'Content-Type': 'application/json'
       }
requestResponse = requests.get("https://api.tiingo.com/api/test?token=5ad45e5247e9f3ddc3a85005ea92c69d1bc4a552",
                                  headers=headers)
print (requestResponse.json())
# Out:
# {'message': 'You successfully sent a request'}
# {'message': 'You successfully sent a request'}
